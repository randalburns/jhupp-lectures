// %% [markdown]
// ### Loop Parallelism

// %%
.L omp

// %%
#include <iostream>
#include <omp.h>

{
  #pragma omp parallel for 
  for ( int i=0; i<100; i++ )
  {
    std::cout << "OMP Thread# " << omp_get_thread_num() << " loop variable " << i << "\n";
  }
}
// Out:
// OMP Thread# 3 loop variable51
// OMP Thread# 3 loop variable52
// OMP Thread# 3 loop variable53
// OMP Thread# 3 loop variable54
// OMP Thread# 3 loop variable55
// OMP Thread# 3 loop variable56
// OMP Thread# 3 loop variable57
// OMP Thread# 3 loop variable58
// OMP Thread# 3 loop variable59
// OMP Thread# 3 loop variable60
// OMP Thread# 3 loop variable61
// OMP Thread# 3 loop variable62
// OMP Thread# 3 loop variable63
// OMP Thread# 3OMP Thread# 0 loop variable0
// OMP Thread# 0 loop variable1
// OMP Thread# 0 loop variable2
// OMP Thread# 0 loop variable3
// OMP Thread# 0 loop variable4
// OMP Thread# 0 loop variable5
// OMP Thread# 0 loop variable6
// OMP Thread# 0 loop variable7
// OMP Thread# 0 loop variable8
// OMP Thread# 0 loop variable9
// OMP Thread# 0 loop variable10
// OMP Thread# 0 loop variable11
// OMP Thread# 0 loop variable12
// OMP Thread# 0 loop variable13
// OMP Thread# 0 loop variable14
// OMP Thread# 0 loop variable15
// OMP Thread# 0 loop variable16
//  loop variable64
// OMP Thread# 3 loop variable65
// OMP Thread# 3 loop variable66
// OMP Thread# 3 loop variable67
// OMP Thread# 2 loop variable34
// OMP Thread# 2 loop variable35
// OMP Thread# 2 loop variable36
// OMP Thread# 2 loop variable37
// OMP Thread# 2 loop variable38
// OMP Thread# 2 loop variable39
// OMP Thread# 2 loop variable40
// OMP Thread# 2 loop variable41
// OMP Thread# 2 loop variable42
// OMP Thread# 2 loop variable43
// OMP Thread# 2 loop variable44
// OMP Thread# 2 loop variable45
// OMP Thread# 2 loop variable46
// OMP Thread# 2 loop variable47
// OMP Thread# 2 loop variable48
// OMP Thread# 2 loop variable49
// OMP Thread# 2 loop variable50
// OMP Thread# 1 loop variable17
// OMP Thread# 1 loop variable18
// OMP Thread# 1 loop variable19
// OMP Thread# 1 loop variable20
// OMP Thread# 1 loop variable21
// OMP Thread# 1 loop variable22
// OMP Thread# 1 loop variable23
// OMP Thread# 1 loop variable24
// OMP Thread# 1 loop variable25
// OMP Thread# 1 loop variable26
// OMP Thread# 1 loop variable27
// OMP Thread# 1 loop variable28
// OMP Thread# 1 loop variable29
// OMP Thread# 1 loop variable30
// OMP Thread# 1 loop variable31
// OMP Thread# 1 loop variable32
// OMP Thread# 1 loop variable33
// OMP Thread# 4 loop variable68
// OMP Thread# O loop variab69
// OMP Thread# 4 loop variable70
// OMP Thread# 4 loop variable71
// OMP Thread# 4572
// OMP Thread#   loop variabled# 2 loop var73
// OMP Thread# 4 loop variable74OOMP Thread# 4 loop variable575 loop variable85OOMP Thread#4 loop variable loop variable86
//
// OMP Thread# OMP Thread# 4577
// 7
// OMP Thread# OMP Thread# 45 loop variable78
// 88
// 4 loop variable579
// OMP Thread# 489 OMP Thread# e805OMP Thread#  loop variable490
// 1
// OMP Thread# 4 loop variable82 loop variableOMP Thread# 4 loop variable83P Thread# 7
// 5 loop variable92
// OMP Thread# 5 loop variable93
// OMP Thread# 5 loop variable94
// OMP Thread# 5 loop variable95
// OMP Thread# 5 loop variable96
// OMP Thread# 5 loop variable97
// OMP Thread# 5 loop variable98
// OMP Thread# 5 loop variable99

// %% [markdown]
// ### Static Scheduling

// %%
#include <iostream>
#include <omp.h>

{
  #pragma omp parallel for schedule(static,4)
  for ( int i=0; i<100; i++ )
  {
    std::cout << "OMP Thread# " << omp_get_thread_num() << " loop variable " << i << "\n";
  }
}
// Out:
// OMP Thread# 0 loop variable 0
// OMP Thread# 0 loop variable 1
// OMP Thread# 0 loop variable 2
// OMP Thread# 0 loop variable 3
// OMP Thread# 0 loop variable 24
// OMP Thread# 0 loop variable 25
// OMP Thread# 0 loop variable 26
// OMP Thread# 0 loop variable 27
// OMP Thread# 0 loop variable 48
// OMP Thread# 0 loop variable 49
// OMP Thread# 0 loop variable 50
// OMP Thread# 0 loop variable 51
// OMP Thread# 0 loop variable 72
// OMP Thread# 0 loop variable 73
// OMP Thread# 0 loop variable 74
// OMP Thread# 0 loop variable 75
// OMP Thread# 0 loop variable 96
// OMP Thread# 0 loop variable 97
// OMP Thread# 0 loop variable 98
// OMP Thread# 0 loop variable 99
// OMP Thread# 4 loop variable 16
// OMP Thread# 4 loop variable 17
// OMP Thread# 4 loop variable 18
// OMP Thread# 4 loop variable 19
// OMP Thread# 4 loop variable 40
// OMP Thread# 4 loop variable 41
// OMP Thread# 4 loop variable 42
// OMP Thread# 4 loop variable 43
// OMP Thread# 4 loop variable 64
// OMP Thread# 4 loop variable 65
// OMP Thread# 4 loop variable 66
// OMP Thread# 4 loop variable 67
// OMP Thread# 4 loop variable 88
// OMP OMP Thread# 0 loop variable 0
// OMP Thread# 0 loop variable 1
// OMP Thread# 0 loop variable 2
// OMP Thread# 0 loop variable 3
// OMP Thread# 0 loop variable 24
// OMP Thread# 0 loop variable 25
// OMP Thread# 0 loop variable 26
// OMP Thread# 0 loop variable 27
// OMP Thread# 0 loop variable 48
// OMP Thread# 0 loop variable 49
// OMP Thread# 0 loop variable 50
// OMP Thread# 0 loop variable 51
// OMP Thread# 0 loop variable 72
// OMP Thread# 0 loop variable 73
// OMP Thread# 0 loop variable 74
// OMP Thread# 0 loop variable 75
// OMP Thread# 0 loop variable 96
// OMP Thread# 0 loop variable 97
// OMP Thread# 0 loop variable 98
// OMP Thread# 0 loop variable 99
// OMP Thread# 4 loop variable 16
// OMP Thread# 4 loop variable 17
// OMP Thread# 4 loop variable 18
// OMP Thread# 4 loop variable 19
// OMP Thread# 4 loop variable 40
// OMP Thread# 4 loop variable 41
// OMP Thread# 4 loop variable 42
// OMP Thread# 4 loop variable 43
// OMP Thread# 4 loop variable 64
// OMP Thread# 4 loop variable 65
// OMP Thread# 4 loop variable 66
// OMP Thread# 4 loop variable 67
// OMP Thread# 4 loop variable 88
// OMP OMP Thread# 0 loop variable 0
// OMP Thread# 0 loop variable 1
// OMP Thread# 0 loop variable 2
// OMP Thread# 0 loop variable 3
// OMP Thread# 0 loop variable 24
// OMP Thread# 0 loop variable 25
// OMP Thread# 0 loop variable 26
// OMP Thread# 0 loop variable 27
// OMP Thread# 0 loop variable 48
// OMP Thread# 0 loop variable 49
// OMP Thread# 0 loop variable 50
// OMP Thread# 0 loop variable 51
// OMP Thread# 0 loop variable 72
// OMP Thread# 0 loop variable 73
// OMP Thread# 0 loop variable 74
// OMP Thread# 0 loop variable 75
// OMP Thread# 0 loop variable 96
// OMP Thread# 0 loop variable 97
// OMP Thread# 0 loop variable 98
// OMP Thread# 0 loop variable 99
// OMP Thread# 4 loop variable 16
// OMP Thread# 4 loop variable 17
// OMP Thread# 4 loop variable 18
// OMP Thread# 4 loop variable 19
// OMP Thread# 4 loop variable 40
// OMP Thread# 4 loop variable 41
// OMP Thread# 4 loop variable 42
// OMP Thread# 4 loop variable 43
// OMP Thread# 4 loop variable 64
// OMP Thread# 4 loop variable 65
// OMP Thread# 4 loop variable 66
// OMP Thread# 4 loop variable 67
// OMP Thread# 4 loop variable 88
// OMP OMP Thread# 5 loop variable 20
// OMP Thread# 5 loop variable 21
// OMP Thread# 5 loop variable 22
// OMP Thread# 5 loop variable 23
// OMP Thread# 5 loop variable 44
// OMP Thread# 5 loop variable 45
// OMP Thread# 5 loop variable 46
// OMP Thread# 5 loop variable 47
// OMP Thread# 5 loop variable 68
// OMP Thread# 5 loop variable 69
// OMP Thread# 5 loop variable 70
// OMP Thread# 5 loop variable 71
// OMP Thread# 5 loop variable 92
// OMP Thread# 5 loop variable 93
// OMP Thread# 5 loop variable 94
// OMP Thread# 5 loop variable 95
// OMP Thread# 1 loop variable 4
// OMP Thread# 1 loop variable 5
// OMP Thread# 1 loop variable 6
// OMP Thread# 1 loop variable 7
// OMP Thread# 1 loop variable 28
// OMP Thread# 1 loop variable 29
// OMP Thread# 1 loop variable 30
// OMP Thread# 1 loop variable 31
// OMP Thread# 1 loop variable 52
// OMP Thread# 1 loop variable 53
// OMP Thread# 1 loop variable 54
// OMP Thread# 1 loop variable 55
// OMP Thread# 1 loop variable 76
// OMP Thread# 1 loop variable 77
// OMP Thread# 1 loop variable 78
// OMP Thread# 1 loop variable 79

// %% [markdown]
// ### Dynamic Scheduling

// %%
#include <iostream>
#include <omp.h>

{
  #pragma omp parallel for schedule(dynamic,4)
  for ( int i=0; i<100; i++ )
  {
    std::cout << "OMP Thread# " << omp_get_thread_num() << " loop variable " << i << "\n";
  }
}
// Out:
// OMP Thread# 5 loop varia30 loop variable  loop variable 40OMP Thread# OMP Thread# 3 loop variable 5
// O loop variable able 23
// OMP3 loop variable OMP Thread# 0 loop variable O
// 3 loop variable 073
// OMP Thread# OMP Thread# 0312
// loop variable v80 loop variable 13OMP Thread#
// OMP Thread# 0 loop variable 9
//
// OMP Thread# O loop variable  variable 7315 loop variable 10P Thread# 710 loop variable
// OMP Thread# 163 OMP Thread# 0 loop variable 17
//
// OMP Thread# 0 loop variable 318
// OMP Thread#  loop variable 24
//  loop variable 19
// OOMP Thread#  loop variable 25
// OMP Thread#  loop variable 328
// OMP Thread# 2 loop variable 22iOMP Thread# OMP Thread#  loop variable 0320oop variable 30
// 27OMP Thread# 20OMP Thread#  loop variable 321OM
// OMP Thread# OMP Thread#  loop variable 33
// 36OMP Thread# 22O3 loop variable OMP Thread#  loop variable 3723
// OMP Thread# OMP Thread# 3MP Thread#   loop variable 33 OMP Thread#
// 40O3 loop variable 23941
// OMP Thread# OMP Thread# O loop varia2 l3 42op variable oopOM
//  Thread#
//
// OMP Thread# 2OMP Thread# 4943
// 3

// %% [markdown]
// ### Guided Scheduling

// %%
#include <iostream>
#include <omp.h>

{
  #pragma omp parallel for schedule(guided)
  for ( int i=0; i<100; i++ )
  {
    std::cout << "OMP Thread# " << omp_get_thread_num() << " loop variable " << i << "\n";
  }
}
